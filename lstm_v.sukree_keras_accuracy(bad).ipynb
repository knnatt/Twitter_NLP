# %% [markdown]
# NLP_df_labeled
# ggl sheet: NLP_df_unlimit_final_more_for_upload

# %%
'''! pip install pandas
! pip install keras
! pip install pythainlp
! pip install scikit-learn
! pip install numpy
! pip install matplotlib
! pip install seaborn'''
# Out:
# '! pip install pandas\n! pip install keras\n! pip install pythainlp'

# %%
import os
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from keras.models import load_model
from pythainlp.tokenize import word_tokenize
from sklearn.metrics import confusion_matrix
from pythainlp.corpus import thai_stopwords
from pythainlp.util import normalize

# %%
def stopwords_rm(text):
    stopwords = set(thai_stopwords())
    stopwords.update(["nan", "-", "_", "", " ", "฿" ,"ค่ะ", "ครับ", "จ้า"])  # Add more stopwords as needed

    # Remove stopwords from the text
    cleaned_text = ' '.join(word for word in text.split() if word not in stopwords)
    return cleaned_text


def deEmojify(text):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642"
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'',text)

def normie(df):
    print('cleaning . . .')
    i = 0 #row number
    df['cleaned1'] = ''
    for row in df['cleaned']:
        clean = ''
        j = row.split(' ') #j is array of string
        for word in j:
            clean = clean + ' ' + normalize(word) #spell(word)[0] #correct(word)
        df['cleaned1'].iloc[i] = clean
        i += 1
    print('done cleaning by normalization')
    return df['cleaned1']
def alone(df):
    print('Are you alone?')
    i = 0 #row number
    df['cleaned1'] = ''
    for row in df['cleaned']:
        words = row.split() #j is array of string
        cleaned = [word for word in words if len(word) > 1]
        cleaned_string = " ".join(cleaned)
        df['cleaned1'].iloc[i] = cleaned_string
        i += 1
    print('done cleaning alone')
    return df['cleaned1']

# %%
df_all = pd.read_csv("./df_y4s2_v1_Natt48.csv") #have chad chat 48 true entries
df_1 = pd.read_csv("./df_y4s2_final_new.csv")

# %%
df_all = df_all.concat(df_1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11448\2202289958.py in ?()
# ----> 1 df_all = df_all.concat(df_1)
#
# c:\Users\natkn\anaconda3\envs\gpt-twitter\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
df_all
# Out:
#      index         username      tweet_id  \
# 0      040     dohyunjinmin  1.723873e+18
# 1      048  Simmons37496127  1.723770e+18
# 2      056        xbiiryxxn  1.723708e+18
# 3      062   BAROCTARISREAL  1.723677e+18
# 4      068        ssssxsaii  1.723592e+18
# ...    ...              ...           ...
# 2794   c44      2024-DD3TDE           NaN
# 2795   c45      2024-46XFZF           NaN
# 2796   c46           WKN67V           NaN
# 2797   c47           WLWMXA           NaN
# 2798   c48      2024-G74TUL           NaN
#
#                                              tweet_text  \
# 0     เคยเดินจาก bts วัดพระศรีฯไปสายสีแดงหลักสี่ ระย...
# 1     เคยเดินจากเซนทรัลลาดพร้าวไปพหลโยธิน 34  คือไม่...
# 2     เคยเดินจากห้วยขวางไปสุทธิสาร สรุปเดินเหยียบฟุต...
# 3     อยู่เกาหลีเดินสะบัด แดกเท่าไหรก็ นน ไม่ขึ้น กล...
# 4     บรรทัดทองจะน่าเดินกว่านี้ถ้า\n-ทำทางเดินใหม่ไม...
# ...                                                 ...
# 2794  แจ้งไปกี่รอบก็เหมือนเดิม  กวนขันวินัยจราจรได้ด...
# 2795  ร้องเรียนทางเท้าชำรุด เป็นหลุมเป็นบ่อ หลายจุด ...
# 2796  ปัญหา: ตลอดทั้งซอยดังกล่าว พบเห็นมีการต่อเติมอ...
# 2797  ปัญหา: ในซอยดังกล่าว ต้องการให้หน่วยงานที่เกี่...
# 2798         ทางเท้าช่วงเย็นคนขับขี่จอดบนทางเท้าเยอะมาก
#
#                                         translated_text         org_step_1  \
# 0     Used to walk from BTS Wat Phra Si to the Laksi...           สนง.โยธา
# 1     I once walked from Central Ladprao to Phahon Y...  สนง.ตำรวจแห่งชาติ
# 2     Used to walk from Huai Khwang to Sutthisan. In...           สนง.โยธา
# 3     In Korea, I walked so hard, no matter how much...           สนง.โยธา
# 4     Banthat Thong would be more worth walking arou...         สนง.เทศกิจ
# ...                                                 ...                ...
# 2794                                                NaN                NaN
# 2795                                                NaN                NaN
# 2796                                                NaN                NaN
# 2797                                                NaN                NaN
# 2798                                                NaN                NaN
#
#              org_step_2  relevant category  \
# 0              สนง.โยธา      True  ทางเท้า
# 1     สนง.ตำรวจแห่งชาติ      True  ทางเท้า
# 2              สนง.โยธา      True  ทางเท้า
# 3              สนง.โยธา      True  ทางเท้า
# 4            สนง.เทศกิจ      True  ทางเท้า
# ...                 ...       ...      ...
# 2794                NaN      True      NaN
# 2795                NaN      True      NaN
# 2796                NaN      True      NaN
# 2797                NaN      True      NaN
# 2798                NaN      True      NaN
#
#                                                   query    datetime_of_tweet  \
# 0     ("ทางเท้า" OR "ทางเดิน" OR "ฟุตบาท") AND ("ประ...   2023-11-13 1:20:19
# 1     ("ทางเท้า" OR "ทางเดิน" OR "ฟุตบาท") AND ("กรุ...  2023-11-12 18:28:11
# 2     ("ทางเท้า" OR "ทางเดิน" OR "ฟุตบาท") AND ("ห้ว...  2023-11-12 14:21:11
# 3     ("ทางเท้า" OR "ทางเดิน" OR "ฟุตบาท") AND ("ห้ว...  2023-11-12 12:18:12
# 4     ("ทางเท้า" OR "ทางเดิน" OR "ฟุตบาท") AND ("นคร...   2023-11-12 6:41:45
# ...                                                 ...                  ...
# 2794                                                NaN                  NaN
# 2795                                                NaN                  NaN
# 2796                                                NaN                  NaN
# 2797                                                NaN                  NaN
# 2798                                                NaN                  NaN
#
#         datetime_of_query                                               link  \
# 0     2023-11-16 15:25:10  https://twitter.com/dohyunjinmin/status/172387...
# 1     2023-11-16 14:52:12  https://twitter.com/Simmons37496127/status/172...
# 2     2023-11-16 15:20:42  https://twitter.com/xbiiryxxn/status/172370751...
# 3     2023-11-16 15:20:42  https://twitter.com/BAROCTARISREAL/status/1723...
# 4     2023-11-16 15:43:02  https://twitter.com/ssssxsaii/status/172359189...
# ...                   ...                                                ...
# 2794                  NaN                                                NaN
# 2795                  NaN                                                NaN
# 2796                  NaN                                                NaN
# 2797                  NaN                                                NaN
# 2798                  NaN                                                NaN
#
#      mentioned_location  location image Chadchad
# 0                พระนคร       0.0    []       no
# 1              ลาดพร้าว       NaN    []       no
# 2              ห้วยขวาง       NaN    []       no
# 3              ห้วยขวาง       NaN    []       no
# 4             บรรทัดทอง       NaN    []       no
# ...                 ...       ...   ...      ...
# 2794                NaN       NaN   NaN      yes
# 2795                NaN       NaN   NaN      yes
# 2796                NaN       NaN   NaN      yes
# 2797                NaN       NaN   NaN      yes
# 2798                NaN       NaN   NaN      yes
#
# [2799 rows x 17 columns]

# %%
df_all[df_all['relevant'] == False].shape[0]
# Out:
# 2543

# %% [markdown]
# random drop false 2287 for resolve imbalance data

# %%
df_a = df_all

np.random.seed(0)

false_rows = df_a[df_a['relevant'] == False]
rows_to_drop = false_rows.sample(n=2287, random_state=42)

# Drop the selected rows from the DataFrame
df_dropped = df_a.drop(rows_to_drop.index)
df_dropped['relevant'].value_counts()
df_a = df_dropped

# %%
#df_a = df_all if want to use all
df_a['relevant'].value_counts() #org can only be English
# Out:
# relevant
# True     256
# False    256
# Name: count, dtype: int64

# %%
#df_a = df_dropped
#df_a = df_all #if use from the sheet
                
df_a['split_text'] = df_a.apply(lambda row: word_tokenize(row['tweet_text'],engine="newmm",keep_whitespace=False), axis=1) #use this
df_a['combined'] = [' '.join(lst) for lst in df_a['split_text']]
df_a['cleaned'] = df_a['combined'].apply(deEmojify)
df_a['cleaned'] = df_a['cleaned'].apply(stopwords_rm) #use in X
#df_a['cleaned'] = normie(df_a)
df_a['cleaned'] = alone(df_a)
df_a['split_cleaned'] = df_a.apply(lambda row: word_tokenize(row['cleaned'],engine="newmm",keep_whitespace=False), axis=1) #use in counting words

#newmm cuts better than nemm-safe ศร, ีฯ ค่,ะ #attacut is virus
#try other engine or break larger, add space in between  
#df_a['split_text2'] = df_a.apply(lambda row: word_tokenize(row['tweet_text'],engine="newmm-safe",keep_whitespace=False), axis=1)'''
# Out:
# Are you alone?
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# C:\Users\natkn\AppData\Local\Temp\ipykernel_11448\3342053473.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned1'].iloc[i] = cleaned_string
# done cleaning alone

# %% [markdown]
# https://pythainlp.github.io/dev-docs/api/tokenize.html

# %%
df_a['relevance_nlp'] = df_a['relevant'].apply(lambda x: 'relevant' if x else 'not relevant')

# %%
df_a
# Out:
#      index         username      tweet_id  \
# 0      040     dohyunjinmin  1.723873e+18
# 1      048  Simmons37496127  1.723770e+18
# 2      056        xbiiryxxn  1.723708e+18
# 3      062   BAROCTARISREAL  1.723677e+18
# 4      068        ssssxsaii  1.723592e+18
# ...    ...              ...           ...
# 2794   c44      2024-DD3TDE           NaN
# 2795   c45      2024-46XFZF           NaN
# 2796   c46           WKN67V           NaN
# 2797   c47           WLWMXA           NaN
# 2798   c48      2024-G74TUL           NaN
#
#                                              tweet_text  \
# 0     เคยเดินจาก bts วัดพระศรีฯไปสายสีแดงหลักสี่ ระย...
# 1     เคยเดินจากเซนทรัลลาดพร้าวไปพหลโยธิน 34  คือไม่...
# 2     เคยเดินจากห้วยขวางไปสุทธิสาร สรุปเดินเหยียบฟุต...
# 3     อยู่เกาหลีเดินสะบัด แดกเท่าไหรก็ นน ไม่ขึ้น กล...
# 4     บรรทัดทองจะน่าเดินกว่านี้ถ้า\n-ทำทางเดินใหม่ไม...
# ...                                                 ...
# 2794  แจ้งไปกี่รอบก็เหมือนเดิม  กวนขันวินัยจราจรได้ด...
# 2795  ร้องเรียนทางเท้าชำรุด เป็นหลุมเป็นบ่อ หลายจุด ...
# 2796  ปัญหา: ตลอดทั้งซอยดังกล่าว พบเห็นมีการต่อเติมอ...
# 2797  ปัญหา: ในซอยดังกล่าว ต้องการให้หน่วยงานที่เกี่...
# 2798         ทางเท้าช่วงเย็นคนขับขี่จอดบนทางเท้าเยอะมาก
#
#                                         translated_text         org_step_1  \
# 0     Used to walk from BTS Wat Phra Si to the Laksi...           สนง.โยธา
# 1     I once walked from Central Ladprao to Phahon Y...  สนง.ตำรวจแห่งชาติ
# 2     Used to walk from Huai Khwang to Sutthisan. In...           สนง.โยธา
# 3     In Korea, I walked so hard, no matter how much...           สนง.โยธา
# 4     Banthat Thong would be more worth walking arou...         สนง.เทศกิจ
# ...                                                 ...                ...
# 2794                                                NaN                NaN
# 2795                                                NaN                NaN
# 2796                                                NaN                NaN
# 2797                                                NaN                NaN
# 2798                                                NaN                NaN
#
#              org_step_2  relevant category  \
# 0              สนง.โยธา      True  ทางเท้า
# 1     สนง.ตำรวจแห่งชาติ      True  ทางเท้า
# 2              สนง.โยธา      True  ทางเท้า
# 3              สนง.โยธา      True  ทางเท้า
# 4            สนง.เทศกิจ      True  ทางเท้า
# ...                 ...       ...      ...
# 2794                NaN      True      NaN
# 2795                NaN      True      NaN
# 2796                NaN      True      NaN
# 2797                NaN      True      NaN
# 2798                NaN      True      NaN
#
#                                                   query  ...  \
# 0     ("ทางเท้า" OR "ทางเดิน" OR "ฟุตบาท") AND ("ประ...  ...
# 1     ("ทางเท้า" OR "ทางเดิน" OR "ฟุตบาท") AND ("กรุ...  ...
# 2     ("ทางเท้า" OR "ทางเดิน" OR "ฟุตบาท") AND ("ห้ว...  ...
# 3     ("ทางเท้า" OR "ทางเดิน" OR "ฟุตบาท") AND ("ห้ว...  ...
# 4     ("ทางเท้า" OR "ทางเดิน" OR "ฟุตบาท") AND ("นคร...  ...
# ...                                                 ...  ...
# 2794                                                NaN  ...
# 2795                                                NaN  ...
# 2796                                                NaN  ...
# 2797                                                NaN  ...
# 2798                                                NaN  ...
#
#      mentioned_location location image Chadchad  \
# 0                พระนคร      0.0    []       no
# 1              ลาดพร้าว      NaN    []       no
# 2              ห้วยขวาง      NaN    []       no
# 3              ห้วยขวาง      NaN    []       no
# 4             บรรทัดทอง      NaN    []       no
# ...                 ...      ...   ...      ...
# 2794                NaN      NaN   NaN      yes
# 2795                NaN      NaN   NaN      yes
# 2796                NaN      NaN   NaN      yes
# 2797                NaN      NaN   NaN      yes
# 2798                NaN      NaN   NaN      yes
#
#                                              split_text  \
# 0     [เคย, เดิน, จาก, bts, วัด, พระ, ศรี, ฯ, ไป, สา...
# 1     [เคย, เดิน, จาก, เซ, นท, รัล, ลาดพร้าว, ไป, พห...
# 2     [เคย, เดิน, จาก, ห้วยขวาง, ไป, สุทธิ, สาร, สรุ...
# 3     [อยู่, เกาหลี, เดิน, สะบัด, แดก, เท่า, ไห, ร, ...
# 4     [บรรทัด, ทอง, จะ, น่า, เดิน, กว่า, นี้, ถ้า, \...
# ...                                                 ...
# 2794  [แจ้ง, ไป, กี่, รอบ, ก็, เหมือนเดิม, กวน, ขัน,...
# 2795  [ร้องเรียน, ทางเท้า, ชำรุด, เป็น, หลุม, เป็น, ...
# 2796  [ปัญหา, :, ตลอดทั้ง, ซอย, ดังกล่าว, พบเห็น, มี...
# 2797  [ปัญหา, :, ใน, ซอย, ดังกล่าว, ต้องการ, ให้, หน...
# 2798  [ทางเท้า, ช่วง, เย็น, คน, ขับขี่, จอด, บน, ทาง...
#
#                                                combined  \
# 0     เคย เดิน จาก bts วัด พระ ศรี ฯ ไป สาย สีแดง หล...
# 1     เคย เดิน จาก เซ นท รัล ลาดพร้าว ไป พหลโยธิน 34...
# 2     เคย เดิน จาก ห้วยขวาง ไป สุทธิ สาร สรุป เดิน เ...
# 3     อยู่ เกาหลี เดิน สะบัด แดก เท่า ไห ร ก็ นน ไม่...
# 4     บรรทัด ทอง จะ น่า เดิน กว่า นี้ ถ้า \n - ทำ ทา...
# ...                                                 ...
# 2794  แจ้ง ไป กี่ รอบ ก็ เหมือนเดิม กวน ขัน วินัย จร...
# 2795  ร้องเรียน ทางเท้า ชำรุด เป็น หลุม เป็น บ่อ หลา...
# 2796  ปัญหา : ตลอดทั้ง ซอย ดังกล่าว พบเห็น มี การต่อ...
# 2797  ปัญหา : ใน ซอย ดังกล่าว ต้องการ ให้ หน่วยงาน ท...
# 2798  ทางเท้า ช่วง เย็น คน ขับขี่ จอด บน ทางเท้า เยอ...
#
#                                                 cleaned  \
# 0     เดิน bts วัด พระ ศรี สาย สีแดง หลัก สี่ ระยะทา...
# 1     เดิน เซ นท รัล ลาดพร้าว พหลโยธิน 34 ไหว พัง อา...
# 2     เดิน ห้วยขวาง สุทธิ สาร สรุป เดิน เหยียบ ฟุตบา...
# 3     เกาหลี เดิน สะบัด แดก ไห นน กลับมา ไทย เดิน พร...
# 4     บรรทัด ทอง เดิน ทำ ทางเดิน แผ่น พื้น กระดก ท่อ...
# ...                                                 ...
# 2794  แจ้ง กี่ รอบ เหมือนเดิม กวน ขัน วินัย จราจร ดี...
# 2795  ร้องเรียน ทางเท้า ชำรุด หลุม บ่อ จุด ถนน กำแพง...
# 2796  ปัญหา ซอย พบเห็น การต่อเติม อาคาร จำนวน สิ่งขอ...
# 2797  ปัญหา ซอย ต้องการ หน่วยงาน เข้ามา ทาสี เส้น ขา...
# 2798                 ทางเท้า เย็น คน ขับขี่ จอด ทางเท้า
#
#                                                cleaned1  \
# 0     เดิน bts วัด พระ ศรี สาย สีแดง หลัก สี่ ระยะทา...
# 1     เดิน เซ นท รัล ลาดพร้าว พหลโยธิน 34 ไหว พัง อา...
# 2     เดิน ห้วยขวาง สุทธิ สาร สรุป เดิน เหยียบ ฟุตบา...
# 3     เกาหลี เดิน สะบัด แดก ไห นน กลับมา ไทย เดิน พร...
# 4     บรรทัด ทอง เดิน ทำ ทางเดิน แผ่น พื้น กระดก ท่อ...
# ...                                                 ...
# 2794  แจ้ง กี่ รอบ เหมือนเดิม กวน ขัน วินัย จราจร ดี...
# 2795  ร้องเรียน ทางเท้า ชำรุด หลุม บ่อ จุด ถนน กำแพง...
# 2796  ปัญหา ซอย พบเห็น การต่อเติม อาคาร จำนวน สิ่งขอ...
# 2797  ปัญหา ซอย ต้องการ หน่วยงาน เข้ามา ทาสี เส้น ขา...
# 2798                 ทางเท้า เย็น คน ขับขี่ จอด ทางเท้า
#
#                                           split_cleaned relevance_nlp
# 0     [เดิน, bts, วัด, พระ, ศรี, สาย, สีแดง, หลัก, ส...      relevant
# 1     [เดิน, เซ, นท, รัล, ลาดพร้าว, พหลโยธิน, 34, ไห...      relevant
# 2     [เดิน, ห้วยขวาง, สุทธิ, สาร, สรุป, เดิน, เหยีย...      relevant
# 3     [เกาหลี, เดิน, สะบัด, แดก, ไห, นน, กลับมา, ไทย...      relevant
# 4     [บรรทัด, ทอง, เดิน, ทำ, ทางเดิน, แผ่น, พื้น, ก...      relevant
# ...                                                 ...           ...
# 2794  [แจ้ง, กี่, รอบ, เหมือนเดิม, กวน, ขัน, วินัย, ...      relevant
# 2795  [ร้องเรียน, ทางเท้า, ชำรุด, หลุม, บ่อ, จุด, ถน...      relevant
# 2796  [ปัญหา, ซอย, พบเห็น, การต่อเติม, อาคาร, จำนวน,...      relevant
# 2797  [ปัญหา, ซอย, ต้องการ, หน่วยงาน, เข้ามา, ทาสี, ...      relevant
# 2798          [ทางเท้า, เย็น, คน, ขับขี่, จอด, ทางเท้า]      relevant
#
# [512 rows x 23 columns]

# %%
df_a['word_length'] = df_a['split_cleaned'].str.len()

# %%
df_a['word_length'].sort_values(ascending=False)
# Out:
# 2768    132
# 2770     93
# 2783     79
# 2797     76
# 2771     76
#        ...
# 2613      4
# 562       4
# 2753      4
# 2758      2
# 1359      2
# Name: word_length, Length: 512, dtype: int64

# %%
from keras.preprocessing.text import Tokenizer
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from sklearn.preprocessing import LabelEncoder
from keras.layers import Embedding, SpatialDropout1D, SpatialDropout1D, LSTM, Dense
from keras.callbacks import EarlyStopping
from keras import backend as K

MAX_WORDS = 2500  # Memorized words
MAX_SEQUENCE_LENGTH = 132 
EMBEDDING_DIM = 100
epochs = 50
batch_size = 32

tokenizer = Tokenizer(num_words=MAX_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~')
tokenizer.fit_on_texts(df_a.cleaned.values)
word_index = tokenizer.word_index
X = tokenizer.texts_to_sequences(df_a.cleaned.values)
X = pad_sequences(X, maxlen=MAX_SEQUENCE_LENGTH)
#Y = df_a['relevance_nlp'].values
label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(df_a['relevance_nlp'].values)
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.20, random_state = 42)

# Define custom metrics
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# Define and compile the model
model = Sequential()
model.add(Embedding(MAX_WORDS, EMBEDDING_DIM, input_length=MAX_SEQUENCE_LENGTH))
#model.add(Dense(64, activation='relu'))
model.add(SpatialDropout1D(0.1))
model.add(LSTM(100, dropout=0.1, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics='accuracy') #, precision_m, recall_m

model.summary()

# Set early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model
history = model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 132, 100)          250000
#
#  spatial_dropout1d_2 (Spati  (None, 132, 100)          0
#  alDropout1D)
#
#  lstm_2 (LSTM)               (None, 100)               80400
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 330501 (1.26 MB)
# Trainable params: 330501 (1.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 11/11 [==============================] - 7s 230ms/step - loss: 0.6911 - accuracy: 0.4985 - val_loss: 0.6909 - val_accuracy: 0.5366
# Epoch 2/50
# 11/11 [==============================] - 2s 158ms/step - loss: 0.6672 - accuracy: 0.6055 - val_loss: 0.6895 - val_accuracy: 0.5610
# Epoch 3/50
# 11/11 [==============================] - 2s 138ms/step - loss: 0.6092 - accuracy: 0.7492 - val_loss: 0.6396 - val_accuracy: 0.7317
# Epoch 4/50
# 11/11 [==============================] - 1s 122ms/step - loss: 0.3942 - accuracy: 0.8991 - val_loss: 0.5235 - val_accuracy: 0.7561
# Epoch 5/50
# 11/11 [==============================] - 1s 109ms/step - loss: 0.3196 - accuracy: 0.9235 - val_loss: 0.5988 - val_accuracy: 0.7195
# Epoch 6/50
# 11/11 [==============================] - 1s 107ms/step - loss: 0.2492 - accuracy: 0.9664 - val_loss: 0.5615 - val_accuracy: 0.7439
# Epoch 7/50
# 11/11 [==============================] - 1s 104ms/step - loss: 0.1678 - accuracy: 0.9786 - val_loss: 0.5159 - val_accuracy: 0.7439
# Epoch 8/50
# 11/11 [==============================] - 1s 113ms/step - loss: 0.1022 - accuracy: 0.9725 - val_loss: 0.4670 - val_accuracy: 0.7927
# Epoch 9/50
# 11/11 [==============================] - 1s 117ms/step - loss: 0.0666 - accuracy: 0.9817 - val_loss: 0.4577 - val_accuracy: 0.8049
# Epoch 10/50
# 11/11 [==============================] - 1s 116ms/step - loss: 0.0450 - accuracy: 0.9908 - val_loss: 0.4669 - val_accuracy: 0.7927
# Epoch 11/50
# 11/11 [==============================] - 1s 114ms/step - loss: 0.0309 - accuracy: 0.9969 - val_loss: 0.4487 - val_accuracy: 0.8293
# Epoch 12/50
# 11/11 [==============================] - 1s 108ms/step - loss: 0.0246 - accuracy: 0.9939 - val_loss: 0.4745 - val_accuracy: 0.8049
# Epoch 13/50
# 11/11 [==============================] - 1s 110ms/step - loss: 0.0214 - accuracy: 0.9969 - val_loss: 0.5060 - val_accuracy: 0.8049
# Epoch 14/50
# 11/11 [==============================] - 1s 115ms/step - loss: 0.0174 - accuracy: 0.9969 - val_loss: 0.5044 - val_accuracy: 0.7927

# %%
from keras.preprocessing.text import Tokenizer
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from sklearn.preprocessing import LabelEncoder
from keras.layers import Embedding, SpatialDropout1D, SpatialDropout1D, LSTM, Dense
from keras.callbacks import EarlyStopping
from keras import backend as K

MAX_WORDS = 2500  # Memorized words
MAX_SEQUENCE_LENGTH = 132 
EMBEDDING_DIM = 100
epochs = 50
batch_size = 32

tokenizer = Tokenizer(num_words=MAX_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~')
tokenizer.fit_on_texts(df_a.cleaned.values)
word_index = tokenizer.word_index
X = tokenizer.texts_to_sequences(df_a.cleaned.values)
X = pad_sequences(X, maxlen=MAX_SEQUENCE_LENGTH)
#Y = df_a['relevance_nlp'].values
label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(df_a['relevance_nlp'].values)
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.20, random_state = 42)

# Define custom metrics
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# Define and compile the model
model = Sequential()
model.add(Embedding(MAX_WORDS, EMBEDDING_DIM, input_length=MAX_SEQUENCE_LENGTH))
#model.add(Dense(64, activation='relu'))
model.add(SpatialDropout1D(0.1))
model.add(LSTM(100, dropout=0.1, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics='accuracy') #, precision_m, recall_m

model.summary()

# Set early stopping to prevent overfitting
#early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model
history = model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, validation_split=0.2)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 132, 100)          250000
#
#  spatial_dropout1d_7 (Spati  (None, 132, 100)          0
#  alDropout1D)
#
#  lstm_7 (LSTM)               (None, 100)               80400
#
#  dense_8 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 330501 (1.26 MB)
# Trainable params: 330501 (1.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 11/11 [==============================] - 7s 205ms/step - loss: 0.6906 - accuracy: 0.5229 - val_loss: 0.6892 - val_accuracy: 0.5488
# Epoch 2/50
# 11/11 [==============================] - 2s 169ms/step - loss: 0.6621 - accuracy: 0.5933 - val_loss: 0.6804 - val_accuracy: 0.5610
# Epoch 3/50
# 11/11 [==============================] - 1s 118ms/step - loss: 0.5938 - accuracy: 0.8349 - val_loss: 0.6047 - val_accuracy: 0.6707
# Epoch 4/50
# 11/11 [==============================] - 1s 107ms/step - loss: 0.4512 - accuracy: 0.8807 - val_loss: 0.5582 - val_accuracy: 0.7439
# Epoch 5/50
# 11/11 [==============================] - 1s 110ms/step - loss: 0.2248 - accuracy: 0.9755 - val_loss: 0.4743 - val_accuracy: 0.7317
# Epoch 6/50
# 11/11 [==============================] - 1s 117ms/step - loss: 0.2945 - accuracy: 0.9174 - val_loss: 0.6874 - val_accuracy: 0.6829
# Epoch 7/50
# 11/11 [==============================] - 1s 117ms/step - loss: 0.1963 - accuracy: 0.9388 - val_loss: 0.6478 - val_accuracy: 0.6463
# Epoch 8/50
# 11/11 [==============================] - 1s 105ms/step - loss: 0.1392 - accuracy: 0.9572 - val_loss: 0.6308 - val_accuracy: 0.7317
# Epoch 9/50
# 11/11 [==============================] - 1s 123ms/step - loss: 0.0921 - accuracy: 0.9694 - val_loss: 0.6432 - val_accuracy: 0.7073
# Epoch 10/50
# 11/11 [==============================] - 1s 111ms/step - loss: 0.0697 - accuracy: 0.9878 - val_loss: 0.6597 - val_accuracy: 0.7195
# Epoch 11/50
# 11/11 [==============================] - 1s 113ms/step - loss: 0.0572 - accuracy: 0.9878 - val_loss: 0.7161 - val_accuracy: 0.7073
# Epoch 12/50
# 11/11 [==============================] - 1s 110ms/step - loss: 0.0417 - accuracy: 0.9939 - val_loss: 0.8257 - val_accuracy: 0.6829
# Epoch 13/50
# 11/11 [==============================] - 1s 109ms/step - loss: 0.0365 - accuracy: 0.9939 - val_loss: 0.8526 - val_accuracy: 0.6829
# Epoch 14/50
# 11/11 [==============================] - 1s 108ms/step - loss: 0.0265 - accuracy: 0.9969 - val_loss: 0.7265 - val_accuracy: 0.7195
# Epoch 15/50
# 11/11 [==============================] - 1s 113ms/step - loss: 0.0290 - accuracy: 0.9939 - val_loss: 0.8076 - val_accuracy: 0.7073
# Epoch 16/50
# 11/11 [==============================] - 1s 112ms/step - loss: 0.0205 - accuracy: 0.9969 - val_loss: 0.9345 - val_accuracy: 0.6707
# Epoch 17/50
# 11/11 [==============================] - 1s 113ms/step - loss: 0.0179 - accuracy: 0.9969 - val_loss: 0.9308 - val_accuracy: 0.6829
# Epoch 18/50
# 11/11 [==============================] - 1s 107ms/step - loss: 0.0156 - accuracy: 0.9969 - val_loss: 0.9138 - val_accuracy: 0.6951
# Epoch 19/50
# 11/11 [==============================] - 1s 108ms/step - loss: 0.0175 - accuracy: 0.9969 - val_loss: 0.9110 - val_accuracy: 0.6707
# Epoch 20/50
# 11/11 [==============================] - 1s 121ms/step - loss: 0.0177 - accuracy: 0.9969 - val_loss: 0.8237 - val_accuracy: 0.6951
# Epoch 21/50
# 11/11 [==============================] - 1s 110ms/step - loss: 0.0183 - accuracy: 0.9939 - val_loss: 0.8730 - val_accuracy: 0.6829
# Epoch 22/50
# 11/11 [==============================] - 1s 107ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.8195 - val_accuracy: 0.6951
# Epoch 23/50
# 11/11 [==============================] - 1s 106ms/step - loss: 0.0106 - accuracy: 0.9969 - val_loss: 0.8348 - val_accuracy: 0.7195
# Epoch 24/50
# 11/11 [==============================] - 1s 105ms/step - loss: 0.0086 - accuracy: 0.9969 - val_loss: 0.9090 - val_accuracy: 0.6707
# Epoch 25/50
# 11/11 [==============================] - 1s 106ms/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 1.0509 - val_accuracy: 0.6829
# Epoch 26/50
# 11/11 [==============================] - 1s 110ms/step - loss: 0.0072 - accuracy: 0.9969 - val_loss: 0.9548 - val_accuracy: 0.6951
# Epoch 27/50
# 11/11 [==============================] - 1s 109ms/step - loss: 0.0070 - accuracy: 0.9969 - val_loss: 1.0151 - val_accuracy: 0.6707
# Epoch 28/50
# 11/11 [==============================] - 1s 110ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.9508 - val_accuracy: 0.6707
# Epoch 29/50
# 11/11 [==============================] - 1s 105ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.9155 - val_accuracy: 0.7195
# Epoch 30/50
# 11/11 [==============================] - 1s 105ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.0937 - val_accuracy: 0.6707
# Epoch 31/50
# 11/11 [==============================] - 1s 103ms/step - loss: 0.0060 - accuracy: 0.9969 - val_loss: 1.0269 - val_accuracy: 0.6585
# Epoch 32/50
# 11/11 [==============================] - 1s 110ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.2056 - val_accuracy: 0.6829
# Epoch 33/50
# 11/11 [==============================] - 1s 111ms/step - loss: 0.0061 - accuracy: 0.9969 - val_loss: 0.9671 - val_accuracy: 0.6707
# Epoch 34/50
# 11/11 [==============================] - 1s 116ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.9201 - val_accuracy: 0.6829
# Epoch 35/50
# 11/11 [==============================] - 1s 112ms/step - loss: 0.0058 - accuracy: 0.9969 - val_loss: 0.9706 - val_accuracy: 0.6951
# Epoch 36/50
# 11/11 [==============================] - 1s 117ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.0099 - val_accuracy: 0.6829
# Epoch 37/50
# 11/11 [==============================] - 2s 155ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.0410 - val_accuracy: 0.6707
# Epoch 38/50
# 11/11 [==============================] - 1s 129ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.0183 - val_accuracy: 0.6707
# Epoch 39/50
# 11/11 [==============================] - 1s 113ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.9462 - val_accuracy: 0.7073
# Epoch 40/50
# 11/11 [==============================] - 1s 117ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.0149 - val_accuracy: 0.6707
# Epoch 41/50
# 11/11 [==============================] - 1s 114ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.0738 - val_accuracy: 0.6707
# Epoch 42/50
# 11/11 [==============================] - 1s 113ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.9576 - val_accuracy: 0.7195
# Epoch 43/50
# 11/11 [==============================] - 1s 118ms/step - loss: 0.0051 - accuracy: 0.9969 - val_loss: 0.8250 - val_accuracy: 0.7317
# Epoch 44/50
# 11/11 [==============================] - 1s 120ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.7661 - val_accuracy: 0.7195
# Epoch 45/50
# 11/11 [==============================] - 1s 116ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.7964 - val_accuracy: 0.7195
# Epoch 46/50
# 11/11 [==============================] - 1s 112ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.8653 - val_accuracy: 0.7073
# Epoch 47/50
# 11/11 [==============================] - 1s 113ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.9197 - val_accuracy: 0.6829
# Epoch 48/50
# 11/11 [==============================] - 1s 114ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.9557 - val_accuracy: 0.7073
# Epoch 49/50
# 11/11 [==============================] - 2s 140ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.9801 - val_accuracy: 0.7073
# Epoch 50/50
# 11/11 [==============================] - 2s 173ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.9998 - val_accuracy: 0.7195

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Evaluate the model on the test set
evaluation = model.evaluate(X_test, Y_test)

loss = evaluation[0]
accuracy = evaluation[1]

# Print evaluation metrics
print('Test set evaluate\n  Loss: {:0.3f}\n  F1 Score: {:0.3f}'.format(loss, accuracy))

y_pred = model.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)

# Calculate precision, recall, and F1 score for the test set
precision = precision_score(Y_test, y_pred_binary, average='weighted')
recall = recall_score(Y_test, y_pred_binary, average='weighted')
f1_metric = (2 * precision * recall)/(precision + recall)

# Print precision, recall, and F1 score
print('Precision: {:0.3f}\nRecall: {:0.3f}\nF1 Score: {:0.3f}\n'.format(precision, recall, f1_metric))
# Out:
# 4/4 [==============================] - 0s 23ms/step - loss: 1.1993 - accuracy: 0.7670
# Test set evaluate
#   Loss: 1.199
#   F1 Score: 0.767
# 4/4 [==============================] - 0s 19ms/step
# Precision: 0.800
# Recall: 0.767
# F1 Score: 0.783

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Evaluate the model on the test set
evaluation = model.evaluate(X_test, Y_test)

loss = evaluation[0]
accuracy = evaluation[1]

# Print evaluation metrics
print('Test set evaluate\n  Loss: {:0.3f}\n  Accuracy score: {:0.3f}'.format(loss, accuracy))

y_pred = model.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)

# Calculate precision, recall, and F1 score for the test set
precision = precision_score(Y_test, y_pred_binary, average='weighted')
recall = recall_score(Y_test, y_pred_binary, average='weighted')
f1_metric = (2 * precision * recall)/(precision + recall)

# Print precision, recall, and F1 score
print('Precision: {:0.3f}\nRecall: {:0.3f}\nF1 Score: {:0.3f}\n'.format(precision, recall, f1_metric))
# Out:
# 4/4 [==============================] - 0s 47ms/step - loss: 0.8774 - accuracy: 0.6990
# Test set evaluate
#   Loss: 0.877
#   Accuracy score: 0.699
# 4/4 [==============================] - 0s 20ms/step
# Precision: 0.750
# Recall: 0.699
# F1 Score: 0.724

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Calculate confusion matrix
cm = confusion_matrix(Y_test, y_pred_binary)

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues, colorbar=False)
plt.title('Confusion Matrix') #put title before to avoid cropping
plt.gcf().set_size_inches(4, 3) 

# Prevent cropping
plt.tight_layout()

#plt.savefig('./img/confusion_relevant_ori_trafbal_notnorm_alone.png') # Save the figure before showing
plt.show()

# %% [markdown]
# save model

# %%
model_json = model.to_json()
with open("./model/relevant_arch_ori_n_trafbal.json", "w") as json_file:
    json_file.write(model_json)
    
model.save_weights('./model/relevant_w_ori_n_trafbal.h5')

# %% [markdown]
# medium

# %%
from keras.models import Sequential
from keras.layers import Embedding, Bidirectional, LSTM, Dense

# Define the model architecture
model = Sequential()

# Add an embedding layer to convert input sequences to dense vectors
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_sequence_length))

# Add a Bidirectional LSTM layer
model.add(Bidirectional(LSTM(units=lstm_units, return_sequences=True)))

# Add a dense output layer
model.add(Dense(units=num_classes, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model.summary()

# %% [markdown]
# old code

# %%
#clean by word_vector (thai2vec) --took 4.38 sec/1 updated 'cleaned1' row
from pythainlp import word_vector
model = word_vector.WordVector(model_name="thai2fit_wv").get_model() #for spell correction
words = model.index_to_key

w_rank = {}
for i,word in enumerate(words):
    w_rank[word] = i

WORDS = w_rank

thai_letters = 'กขฃคฅฆงจฉชซฌญฎฏฐฑฒณดตถทธนบปผฝพฟภมยรฤฤๅลฦฦๅวศษสหฬอฮะัาำิีึืุูเแโใไ็่้๊๋์'

def words(text): return re.findall(r'\w+', text.lower())

def P(word):
    "Probability of `word`."
    # use inverse of rank as proxy
    # returns 0 if the word isn't in the dictionary
    return - WORDS.get(word, 0)

def correction(word):
    "Most probable spelling correction for word."
    return max(candidates(word), key=P)

def candidates(word):
    "Generate possible spelling corrections for word."
    return (known([word]) or known(edits1(word)) or known(edits2(word)) or [word])

def known(words):
    "The subset of `words` that appear in the dictionary of WORDS."
    return set(w for w in words if w in WORDS)

def edits1(word):
    "All edits that are one edit away from `word`."
    letters    = thai_letters
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word):
    "All edits that are two edits away from `word`."
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Calculate confusion matrix
cm = confusion_matrix(Y_test, y_pred_binary)

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues, colorbar=False)

# Get current axis and adjust figure size to fit the matrix
plt.gca().set_aspect('equal', adjustable='box')
plt.gcf().set_size_inches(cm.shape[1], cm.shape[0])  # Set figure size based on matrix dimensions

plt.title('Confusion Matrix')

# Save the figure before showing
plt.savefig('./img/confusion_relevant_ori_trafbal') #_ori_trafbal'

plt.show()

# %%
accr = model.evaluate(X_test, Y_test)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accr[0], accr[1]))


# Get predictions for the test set
y_pred = np.argmax(model.predict(X_test), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 accr = model.evaluate(X_test, Y_test)
#       2 print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accr[0], accr[1]))
#       5 # Get predictions for the test set
#
# NameError: name 'model' is not defined

# %%
from sklearn.metrics import roc_auc_score
score = roc_auc_score(Y_test, y_pred)
print('ROC AUC: %.3f' % score)
cm = confusion_matrix(Y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(4, 3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# ROC AUC: 0.500
